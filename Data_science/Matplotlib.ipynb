# %% [markdown]
# # Matplotlib

# %% [markdown]
# Biblioteka `matplotlib` jest podstawową biblioteką do tworzenia wizualizacji w Pythonie. Jego największymi zaletami są uniwersalność i powszechność - w internecie znajdziemy mnóstwo informacji na temat tego jak używać tego pakietu i tworzyć w nim wizualizacje.
#
# Jest uważana za "dziadka" tego typu narzędzi w Pythonie. Została stworzona przez Johna Huntera w celu odtworzenia możliwości tworzenia wykresów znanych z MatLaba (innego języka programowania) w Pythonie. Jeśli więc znasz Matlaba, korzystanie z Matplotlib będzie dla ciebie naturalne.
#
# Inne biblioteki to: Seaborn oraz Plotly.
#
# To doskonała biblioteka do tworzenia grafiki 2D i 3D do generowania wykresów naukowych.
#
# Oto kilka głównych zalet Matplotlib:
#
# - Ogólnie łatwa inicjacja w przypadku prostych wykresów
# - Wsparcie dla niestandardowych etykiet i tekstów
# - Doskonała kontrola nad każdym elementem na wykresie
# - Wysokiej jakości generowanie wyjścia w wielu formatach
# - Ogólna możliwość dużego dostosowania
#
# Matplotlib pozwala tworzyć replikowalne wykresy programowo. Nauczmy się, jak z niej korzystać! Oficjalna strona internetowa Matplotlib: https://matplotlib.org/

# %% [markdown]
# ### Importy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Pierwszy wykres w matplotlib

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y)

# %% [markdown]
# Możemy również tworzyć podwykresy, czyli wykresy które są obok siebie

# %%
plt.subplot(1, 2, 1) # (wiersze, kolumny, numer panelu)
plt.plot(x, y)

plt.subplot(1, 2, 2)
plt.plot(y, x)

plt.savefig('my_plot.png')

# %% [markdown]
# Z racji tego, że matplotlib powstał jako alternatywa dla użytkowników programu MATLAB, istnieje w nim interfejs `pyplot`, który jest analogią do interfejsu istniejącego w MATLAB. Jest to bardziej techniczny interfejs powiązany z obiektami pythonowymi.

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(x, y)

# %% [markdown]
# ### Zapisywanie wykresu do pliku

# %%
fig.savefig('my_plot.png')

# %%
from IPython.display import Image
Image('my_plot.png')

# %%
import matplotlib.image as mpimg
image = mpimg.imread('my_plot.png')
plt.imshow(image)

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 100)
y = np.sin(x)
ax.plot(x, y)
ax.axhline(y=0, color='red')
ax.axvline(x=0, color='red')

# %%
fig, ax = plt.subplots(nrows=2)

ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %% [markdown]
# Jeżeli chcemy kilka serii danych (wykresów) na raz możemy używać `plt.plot` wiele razy:

# %%
plt.plot(x, np.sin(x))
plt.plot(x, 2 * np.sin(x))

# %% [markdown]
# Aby zarządzać kolorami możemy użyć parametru `color`, oto kilka sposobów używania go:

# %%
plt.plot(x, np.sin(x - 0), color='purple')      # nazwa koloru
plt.plot(x, np.sin(x - 1), color='r')           # kod koloru (rgbcmykw)
plt.plot(x, np.sin(x - 2), color='#FFDD44')     # hex RRGGBB
plt.plot(x, np.sin(x - 3), color=(0.65, 0.6, 0.5)) # trójka reprezentująca wartości RGB (red, green, blue)

# %% [markdown]
# Analogicznie możemy definiować styl linii za pomocą `linestyle`

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# Lub korzystając ze skrótów:
plt.plot(x, x + 4, linestyle='-')
plt.plot(x, x + 5, linestyle='--') 
plt.plot(x, x + 6, linestyle='-.') 
plt.plot(x, x + 7, linestyle=':');

# %% [markdown]
# Możemy też łączyć ze sobą te komendy:

# %%
plt.plot(x, x + 0, 'g-')
plt.plot(x, x + 1, '--c')
plt.plot(x, x + 2, '-.k')
plt.plot(x, x + 3, 'r:');

# %% [markdown]
# ### Ustawianie zakresu osi

# %%
plt.plot(x, np.sin(x), '-b')

plt.xlim(-2, 12)  # zakres osi OX
plt.ylim(-1.5, 10);  # zakres osi OY

# %% [markdown]
# ### Dodawanie oznaczeń do wykresów

# %%
plt.plot(x, np.sin(x))
plt.title("A Sin Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# Kiedy pokazujemy więcej niż jedną serie danych możemy skorzystać z `plt.legend` aby dodać legendę do wykresu:

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')

plt.legend(loc='best');

# %%
import matplotlib.pyplot as plt
import pandas as pd

x = np.linspace(0, 10, 100)
y = (x + 11) / 3

df = pd.DataFrame(data={"x": x,
                        "y": y})

plt.plot(df.loc[:, 'x'], df.loc[:, 'y'], '--c', label='my plot')
plt.xlabel("x")
plt.ylabel("y", color='blue')
plt.title("My plot", color='red')
plt.xlim(0, 10)
plt.ylim(3, 7)

plt.legend(loc='best')

# %% [markdown]
# Jeżeli korzystamy z obiektowego interfejsu nazwy metod mogą być trochę inne:
#
# - `plt.xlabel()` → `ax.set_xlabel()`
# - `plt.ylabel()` → `ax.set_ylabel()`
# - `plt.xlim()` → `ax.set_xlim()`
# - `plt.ylim()` → `ax.set_ylim()`
# - `plt.title()` → `ax.set_title()`

# %% [markdown]
# Aby ułatwić sobie pracę możemy skorzystać z `ax.set` i ustawić wszystko za jednym razem:

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(df.loc[:, 'x'], df.loc[:, 'y'], '-r', label='my_plot')

ax.set(xlim=(0, 10), ylim=(3, 7),
       xlabel='x', ylabel='y',
       title='A Simple Plot')

ax.title.set_color('blue')
ax.xaxis.label.set_color('purple')

ax.legend()

# %% [markdown]
# ### Wykresy kropkowe (scatter plots)

# %% [markdown]
# Wykresy kropkowe tworzymy dokładnie tak jak liniowe, zmieniamy jedynie symbol który jest używany do rysowania:

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, 'o');

# %% [markdown]
# Co więcej symbole można ze sobą łączyć:

# %%
plt.plot(x, y, 'r*-')
# plt.plot(x, y, linestyle='', color="red", marker="*")

# %% [markdown]
# Funkcja `plot` posiada wiele parametrów służacych do modyfikowania stylu linii i punktów:

# %%
plt.figure(figsize=(10,5))

plt.plot(x, y, color='gray',
         linestyle='solid', linewidth=3,
         marker='s',
         markersize=7,
         markerfacecolor='blue',
         markeredgecolor='red',
         markeredgewidth=2
        )

plt.axis('tight');

# %% [markdown]
# Inne style markerów można znaleźć na stronie: https://matplotlib.org/stable/api/markers_api.html

# %% [markdown]
# Jeżeli chcemy tworzyć bardziej skomplikowane wykresy kropkowe, możemy skorzystać z `plt.scatter` które daje nam możliwość ustalania stylu dla każdej obserwacji:

# %%
plt.scatter?
# Out:
# Signature:
# plt.scatter(
#     x,
#     y,
#     s=None,
#     c=None,
#     marker=None,
#     cmap=None,
#     norm=None,
#     vmin=None,
#     vmax=None,
#     alpha=None,
#     linewidths=None,
#     *,
#     edgecolors=None,
#     plotnonfinite=False,
#     data=None,
#     **kwargs,
# )
# Docstring:
# A scatter plot of *y* vs. *x* with varying marker size and/or color.
#
# Parameters
# ----------
# x, y : float or array-like, shape (n, )
#     The data positions.
#
# s : float or array-like, shape (n, ), optional
#     The marker size in points**2 (typographic points are 1/72 in.).
#     Default is ``rcParams['lines.markersize'] ** 2``.
#
# c : array-like or list of colors or color, optional
#     The marker colors. Possible values:
#
#     - A scalar or sequence of n numbers to be mapped to colors using
#       *cmap* and *norm*.
#     - A 2D array in which the rows are RGB or RGBA.
#     - A sequence of colors of length n.
#     - A single color format string.
#
# ...

# %%
plt.scatter(x, y, c='darkblue', s=10)

# %% [markdown]
# ### Tworzenie histogramów

# %% [markdown]
# Histogramy są świetnym narzędziem na początkowym etapie analizy zbioru danych, aby lepiej zrozumieć ich rozkład.

# %%
data = np.random.randn(1000)
plt.hist(data);

# %%
data[:10]
# Out:
# array([-1.31848201, -0.08263234, -1.25445594,  0.46500122,  0.19644273,
#         0.33340024,  1.07447684, -0.6071431 ,  0.0774684 ,  0.90199447])

# %%
plt.hist(data, bins=30, alpha=0.5, histtype='bar', color='steelblue', edgecolor='red');

# %%
plt.hist?
# Out:
# Signature:
# plt.hist(
#     x,
#     bins=None,
#     range=None,
#     density=False,
#     weights=None,
#     cumulative=False,
#     bottom=None,
#     histtype='bar',
#     align='mid',
#     orientation='vertical',
#     rwidth=None,
#     log=False,
#     color=None,
#     label=None,
#     stacked=False,
#     *,
#     data=None,
#     **kwargs,
# )
# Docstring:
# Compute and plot a histogram.
#
# This method uses `numpy.histogram` to bin the data in *x* and count the
# number of values in each bin, then draws the distribution either as a
# `.BarContainer` or `.Polygon`. The *bins*, *range*, *density*, and
# *weights* parameters are forwarded to `numpy.histogram`.
#
# If the data has already been binned and counted, use `~.bar` or
# `~.stairs` to plot the distribution::
#
#     counts, bins = np.histogram(x)
#     plt.stairs(counts, bins)
#
# Alternatively, plot pre-computed bins and counts using ``hist()`` by
# ...

# %%
x1 = np.random.normal(0, 0.5, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='bar', alpha=0.3, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# ### Tworzenie boxplotów

# %% [markdown]
# Boxploty to wykresy skrzynkowe.

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

plt.boxplot(data, vert=True, patch_artist=True);

# %% [markdown]
# ### Częsci wykresu matplotlib

# %% [markdown]
# ![Screenshot%20from%202023-08-30%2017-40-48.png](attachment:Screenshot%20from%202023-08-30%2017-40-48.png)

# %% [markdown]
# ## Ćwiczenia

# %% [markdown]
# ### Ćwiczenie 1

# %% [markdown]
# 1. Utwórz obiekt figury o nazwie "fig" za pomocą plt.figure(). Zmień przy okazji rozmiar wykresu na (4, 4).
# 2. Użyj `plt.plot`, wyświetlić wyklres.
# 3. Nanieś (x, y) na tę oś i ustaw etykiety oraz tytuły, aby pasowały do poniższego wykresu:

# %%
# Dane
x = np.array([0, 50, 100])
y = np.array([0, 100, 200])

# %%
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig = plt.figure(figsize=(4, 4))
ax = plt.axes()

ax.plot(x, y)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ### Ćwiczenie 2

# %% [markdown]
# Dla poniższych danych odtwórz wykres który jest poniżej. Dodaj `linestyle`, `color` oraz `label` do obydwu lini. Zmień podpisy osi, tytuł oraz wyświetl legendę.

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
y2 = [1, 3, 5, 7, 9]

# %%
plt.plot(x, y1, linestyle='-', color='blue', label='Line 1')
plt.plot(x, y2, linestyle='--', color='orange', label='Line 2')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Line Plots')
plt.legend()
